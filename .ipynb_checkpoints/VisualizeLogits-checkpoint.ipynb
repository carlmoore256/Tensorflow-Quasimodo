# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
file_dir = './saved_logits/'

files = glob.glob(file_dir + '*.npy')
print(len(files))
# Out:
# 21

# %%
for f in files:
    logit = np.load(f)
    plt.plot(logit[0,:,0])
    ipd.display(ipd.Audio(logit[0,:,0], rate=44100, autoplay=False))
    plt.show()
